# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading the data

# %%
path=r'B:\MY COMPUTER (HOME)\2 IT\Practice works\Datasets\SC-EST2020-ALLDATA6.csv'
raw_data=pd.read_csv(path)

# %%
# Show top 5 records from the data
raw_data.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE     NAME  SEX  ORIGIN  RACE  AGE  \
# 0      40       3         6      1  Alabama    0       0     1    0
# 1      40       3         6      1  Alabama    0       0     1    1
# 2      40       3         6      1  Alabama    0       0     1    2
# 3      40       3         6      1  Alabama    0       0     1    3
# 4      40       3         6      1  Alabama    0       0     1    4
#
#    CENSUS2010POP  ...  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0          37991  ...            37624            36611            37387
# 1          38150  ...            38427            37653            36766
# 2          39738  ...            37611            38362            37572
# 3          39827  ...            38133            37677            38438
# 4          39353  ...            39638            38148            37719
#
#    POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  POPESTIMATE2018  \
# ...

# %%
# shape of dataset
data=raw_data.copy()
data.shape
# Out:
# (236844, 23)

# %%
# basic info of dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236844 entries, 0 to 236843
# Data columns (total 23 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   SUMLEV             236844 non-null  int64
#  1   REGION             236844 non-null  int64
#  2   DIVISION           236844 non-null  int64
#  3   STATE              236844 non-null  int64
#  4   NAME               236844 non-null  object
#  5   SEX                236844 non-null  int64
#  6   ORIGIN             236844 non-null  int64
#  7   RACE               236844 non-null  int64
#  8   AGE                236844 non-null  int64
#  9   CENSUS2010POP      236844 non-null  int64
#  10  ESTIMATESBASE2010  236844 non-null  int64
#  11  POPESTIMATE2010    236844 non-null  int64
#  12  POPESTIMATE2011    236844 non-null  int64
#  13  POPESTIMATE2012    236844 non-null  int64
#  14  POPESTIMATE2013    236844 non-null  int64
#  15  POPESTIMATE2014    236844 non-null  int64
# ...

# %%
# Find the duplicate records and removing the same.
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [SUMLEV, REGION, DIVISION, STATE, NAME, SEX, ORIGIN, RACE, AGE, CENSUS2010POP, ESTIMATESBASE2010, POPESTIMATE2010, POPESTIMATE2011, POPESTIMATE2012, POPESTIMATE2013, POPESTIMATE2014, POPESTIMATE2015, POPESTIMATE2016, POPESTIMATE2017, POPESTIMATE2018, POPESTIMATE2019, POPESTIMATE042020, POPESTIMATE2020]
# Index: []
#
# [0 rows x 23 columns]

# %%
# To show the count of null values in each column
data.isnull().sum()
# Out:
# SUMLEV               0
# REGION               0
# DIVISION             0
# STATE                0
# NAME                 0
# SEX                  0
# ORIGIN               0
# RACE                 0
# AGE                  0
# CENSUS2010POP        0
# ESTIMATESBASE2010    0
# POPESTIMATE2010      0
# POPESTIMATE2011      0
# POPESTIMATE2012      0
# POPESTIMATE2013      0
# POPESTIMATE2014      0
# POPESTIMATE2015      0
# POPESTIMATE2016      0
# POPESTIMATE2017      0
# POPESTIMATE2018      0
# POPESTIMATE2019      0
# POPESTIMATE042020    0
# POPESTIMATE2020      0
# dtype: int64

# %%
# To view all unique values or categories in each column
data.nunique()
# Out:
# SUMLEV                   1
# REGION                   4
# DIVISION                 9
# STATE                   51
# NAME                    51
# SEX                      3
# ORIGIN                   3
# RACE                     6
# AGE                     86
# CENSUS2010POP        30253
# ESTIMATESBASE2010    30261
# POPESTIMATE2010      30316
# POPESTIMATE2011      30371
# POPESTIMATE2012      30601
# POPESTIMATE2013      30673
# POPESTIMATE2014      30708
# POPESTIMATE2015      30893
# POPESTIMATE2016      31004
# POPESTIMATE2017      31114
# POPESTIMATE2018      31198
# POPESTIMATE2019      31279
# POPESTIMATE042020    31306
# POPESTIMATE2020      31360
# dtype: int64

# %% [markdown]
# To analyse the dataset, below are snippets of code that you can use as helper functions to visualise different columns within the dataset. They include:
#
# - plot_continuous_distribution = this is to visualise the distribution of numeric columns
# - plot_categorical_distribution = this is to visualise the distribution of categorical columns

# %%
def plot_continuous_distribution(data: pd.DataFrame = None, column: str = None, height: int = 8):
  _ = sns.displot(data, x=column, kde=True, height=height, aspect=height/5).set(title=f'Distribution of {column}');

def get_unique_values(data, column):
  num_unique_values = len(data[column].unique())
  value_counts = data[column].value_counts()
  print(f"Column: {column} has {num_unique_values} unique values\n")
  print(value_counts)

def plot_categorical_distribution(data: pd.DataFrame = None, column: str = None, height: int = 8, aspect: int = 2):
  _ = sns.catplot(data=data, x=column, kind='count', height=height, aspect=aspect).set(title=f'Distribution of {column}');

# %%
# Distibution of region 
plot_continuous_distribution(data, 'REGION')

# %% [markdown]
# This chart shows that Region category 3 having highest frequency and Region 1 being lowest.

# %%
# Distibution of Division 
plot_continuous_distribution(data, 'DIVISION')

# %% [markdown]
# This tells us that 5th Division having highest frequency with 2nd being least one.

# %%
# Unique values of State column
get_unique_values(data, 'STATE')
# Out:
# Column: STATE has 51 unique values
#
# 1     4644
# 42    4644
# 32    4644
# 33    4644
# 34    4644
# 35    4644
# 36    4644
# 37    4644
# 38    4644
# 39    4644
# 40    4644
# 41    4644
# 44    4644
# 30    4644
# 45    4644
# 46    4644
# 47    4644
# 48    4644
# 49    4644
# 50    4644
# 51    4644
# 53    4644
# 54    4644
# 55    4644
# 31    4644
# 29    4644
# 2     4644
# 16    4644
# 4     4644
# 5     4644
# 6     4644
# 8     4644
# 9     4644
# 10    4644
# 11    4644
# 12    4644
# 13    4644
# 15    4644
# 17    4644
# 28    4644
# 18    4644
# 19    4644
# 20    4644
# 21    4644
# 22    4644
# 23    4644
# 24    4644
# 25    4644
# 26    4644
# 27    4644
# 56    4644
# Name: STATE, dtype: int64

# %%
# Distibution of STATE 
plot_continuous_distribution(data, 'STATE')

# %%
# Unique values of NAME column
get_unique_values(data, 'NAME')
# Out:
# Column: NAME has 51 unique values
#
# Alabama                 4644
# Pennsylvania            4644
# Nevada                  4644
# New Hampshire           4644
# New Jersey              4644
# New Mexico              4644
# New York                4644
# North Carolina          4644
# North Dakota            4644
# Ohio                    4644
# Oklahoma                4644
# Oregon                  4644
# Rhode Island            4644
# Montana                 4644
# South Carolina          4644
# South Dakota            4644
# Tennessee               4644
# Texas                   4644
# Utah                    4644
# Vermont                 4644
# Virginia                4644
# Washington              4644
# West Virginia           4644
# Wisconsin               4644
# Nebraska                4644
# Missouri                4644
# Alaska                  4644
# Idaho                   4644
# Arizona                 4644
# Arkansas                4644
# California              4644
# ...

# %%
# Distribution of 'NAME' column
plot_categorical_distribution(data, 'NAME', height=10, aspect=3.5)

# %% [markdown]
# Above two charts doesn't give any insights and having 51 unique values. So, it's useless to consider for further analysis and visualization.

# %%
# Distibution of SEX 
plot_continuous_distribution(data, 'SEX')

# %%
# Distibution of ORIGIN 
plot_continuous_distribution(data, 'ORIGIN')

# %% [markdown]
# The sex and Origin categories having only 3 unique values and above chart shows each category distributed evenly.

# %%
# Distibution of RACE 
plot_continuous_distribution(data, 'RACE')

# %% [markdown]
# This chart shows that 6 Race categories with evenly distributed each.

# %%
data.dtypes
# Out:
# SUMLEV                int64
# REGION                int64
# DIVISION              int64
# STATE                 int64
# NAME                 object
# SEX                   int64
# ORIGIN                int64
# RACE                  int64
# AGE                   int64
# CENSUS2010POP         int64
# ESTIMATESBASE2010     int64
# POPESTIMATE2010       int64
# POPESTIMATE2011       int64
# POPESTIMATE2012       int64
# POPESTIMATE2013       int64
# POPESTIMATE2014       int64
# POPESTIMATE2015       int64
# POPESTIMATE2016       int64
# POPESTIMATE2017       int64
# POPESTIMATE2018       int64
# POPESTIMATE2019       int64
# POPESTIMATE042020     int64
# POPESTIMATE2020       int64
# dtype: object

# %%
import panel as pn
import plotly.graph_objects as
# Out:
#                    SUMLEV        REGION      DIVISION         STATE  \
# SUMLEV                NaN           NaN           NaN           NaN
# REGION                NaN  1.000000e+00  9.674865e-01 -1.412917e-01
# DIVISION              NaN  9.674865e-01  1.000000e+00 -1.399096e-01
# STATE                 NaN -1.412917e-01 -1.399096e-01  1.000000e+00
# SEX                   NaN -1.274254e-15 -1.494440e-15 -9.327081e-16
# ORIGIN                NaN -2.182416e-15 -2.171124e-15  8.965148e-15
# RACE                  NaN -1.427905e-16 -1.092569e-15 -3.870595e-15
# AGE                   NaN -2.184614e-15 -1.654133e-15 -5.070836e-15
# CENSUS2010POP         NaN -2.417793e-03  9.946776e-03 -2.556450e-02
# ESTIMATESBASE2010     NaN -2.417292e-03  9.945477e-03 -2.556892e-02
# POPESTIMATE2010       NaN -2.259162e-03  1.011794e-02 -2.555262e-02
# POPESTIMATE2011       NaN -1.539479e-03  1.093194e-02 -2.557428e-02
# POPESTIMATE2012       NaN -7.145774e-04  1.181123e-02 -2.558581e-02
# ...
